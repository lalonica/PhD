# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import math

# %%
#np.savetxt('portion1Set.txt', dim2_array, delimiter = '\t')

# %%
array_data = np.genfromtxt('D:\\zzzLola\\PhD\\DataSet\\US101\\test\\small.txt',
                           delimiter = '\t')

# %%
array_data
# Out:
# array([[  1.07300000e+03,   3.21100000e+03,   5.87000000e+02,
#           1.11884730e+12,   2.00970000e+01,   1.99936700e+03,
#           6.45259529e+06,   1.87202629e+06,   1.25000000e+01,
#           5.00000000e+00,   2.00000000e+00,   5.99200000e+01,
#          -1.71000000e+00,   2.00000000e+00,   0.00000000e+00,
#           1.08300000e+03,   0.00000000e+00,   0.00000000e+00],
#        [  1.07300000e+03,   3.21200000e+03,   5.87000000e+02,
#           1.11884730e+12,   2.00250000e+01,   2.00536800e+03,
#           6.45260000e+06,   1.87202254e+06,   1.25000000e+01,
#           5.00000000e+00,   2.00000000e+00,   5.96000000e+01,
#          -4.46000000e+00,   2.00000000e+00,   0.00000000e+00,
#           1.08300000e+03,   0.00000000e+00,   0.00000000e+00],
#        [  1.07300000e+03,   3.21300000e+03,   5.87000000e+02,
#           1.11884730e+12,   1.99730000e+01,   2.01131400e+03,
#           6.45260465e+06,   1.87201882e+06,   1.25000000e+01,
# ...

# %%
array_data.dtype
# Out:
# dtype('float64')

# %%
array_data.ndim
# Out:
# 2

# %%
array_data.shape[0]
# Out:
# 30L

# %%
array_data[0,:]
# Out:
# array([  1.07300000e+03,   3.21100000e+03,   5.87000000e+02,
#          1.11884730e+12,   2.00970000e+01,   1.99936700e+03,
#          6.45259529e+06,   1.87202629e+06,   1.25000000e+01,
#          5.00000000e+00,   2.00000000e+00,   5.99200000e+01,
#         -1.71000000e+00,   2.00000000e+00,   0.00000000e+00,
#          1.08300000e+03,   0.00000000e+00,   0.00000000e+00])

# %%
dist_list = []

# %%
dist_med = []

# %%
dist_list
# Out:
# []

# %%
def calculateDistance(x1,y1,x2,y2):  
     dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)  
     return dist

# %%
count = 0
for i in xrange(0, array_data.shape[0]):
    if (i+1):
        j = i + 1
        for j in xrange(0, array_data.shape[0]):
            if array_data[i,3] == array_data[j,3] and array_data[i,0] != array_data[j,0]:
                count += 1
                dist = calculateDistance(array_data[i,6],array_data[i,7],array_data[j,6],array_data[j,7])
                #i_data = array_data.tolist
                dist_med = (array_data[i, 3], array_data[i, 0], array_data[j,0], dist, array_data[i, 10], array_data[i, 11], 
                            array_data[i, 13],array_data[i, 14], array_data[i, 15])
                dist_list.append(dist_med)
            
print count
# Out:
# 18

# %%
dist_list
# Out:
# [(1118847300000.0,
#   1073.0,
#   1077.0,
#   87.79801093960633,
#   2.0,
#   59.920000000000002,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300100.0,
#   1073.0,
#   1077.0,
#   88.26400943796544,
#   2.0,
#   59.600000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300200.0,
#   1073.0,
#   1077.0,
#   88.78257726059938,
#   2.0,
#   59.140000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300300.0,
#   1073.0,
#   1077.0,
#   89.45574294638138,
#   2.0,
#   58.780000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300400.0,
#   1073.0,
#   1077.0,
#   90.12657588592877,
#   2.0,
#   58.780000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300500.0,
#   1073.0,
#   1077.0,
#   91.24342243700137,
#   2.0,
#   59.140000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300600.0,
#   1073.0,
#   1077.0,
#   91.79087139771838,
#   2.0,
#   59.600000000000001,
#   2.0,
#   0.0,
#   1083.0),
#  (1118847300600.0,
#   1073.0,
#   6666.0,
#   340.1018436763074,
# ...

# %%
np.savetxt('D:\\zzzLola\\PhD\\DataSet\\US101\\test\\dist_small.txt',dist_list, fmt='%.10e', delimiter='\t', newline='\n')

# %%
cont2 = 0 
for i in xrange(0, dist_array.shape[0]):
    for j in xrange(0, dist_array.shape[0]):
        print (dist_array[i,0], dist_array[j,0])
        if (dist_array[i,0] == dist_array[j,0]) and (dist_array[i,1] == dist_array[j,2]) and (dist_array[i,2]==dist_array[j,1]):

            #print dist_array[i,0], dist_array[j,0], dist_array[i,1], dist_array[j,2], dist_array[i,2], dist_array[j,1]
            med_norep = (dist_array[i,0], dist_array[i,1], dist_array[i,2], dist_array[i,3])
            dis_norep.append(med_norep)
# Out:
# (1118846980200.0, 1118846980200.0)
# (1118846980200.0, 1118846980300.0)
# (1118846980200.0, 1118846980400.0)
# (1118846980200.0, 1118846980500.0)
# (1118846980200.0, 1118846980600.0)
# (1118846980200.0, 1118846980700.0)
# (1118846980200.0, 1118846980800.0)
# (1118846980200.0, 1118846980900.0)
# (1118846980200.0, 1118846981000.0)
# (1118846980200.0, 1118846981100.0)
# (1118846980200.0, 1118846981200.0)
# (1118846980200.0, 1118846981300.0)
# (1118846980200.0, 1118846981400.0)
# (1118846980200.0, 1118846981500.0)
# (1118846980200.0, 1118846981600.0)
# (1118846980200.0, 1118846981700.0)
# (1118846980200.0, 1118846981800.0)
# (1118846980200.0, 1118846981900.0)
# (1118846980200.0, 1118846982000.0)
# (1118846980200.0, 1118846982100.0)
# (1118846980200.0, 1118846982200.0)
# (1118846980200.0, 1118846982300.0)
# (1118846980200.0, 1118846982400.0)
# (1118846980200.0, 1118846982500.0)
# (1118846980200.0, 1118846982600.0)
# (1118846980200.0, 1118846982700.0)
# (1118846980200.0, 1118846982800.0)
# ...
